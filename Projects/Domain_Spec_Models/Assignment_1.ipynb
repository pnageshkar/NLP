# %%
import string
import re
import pandas as pd
from nltk.tokenize import word_tokenize

# %%
# Read the csv file in to a pandas dataframe
df = pd.read_csv('C:\\Users\\HP M6\\NLP\\Build_DomSp_Models\\Data\\stackexchange_812k.csv.gz', 
                 compression='gzip', header=0, sep=',', quotechar='"')
df.tail()
# Out:
#         post_id  parent_id  comment_id  \
# 812127   279994        NaN    536471.0
# 812128   279998        NaN    536439.0
# 812129   279998        NaN    536514.0
# 812130   279999        NaN    536802.0
# 812131   279999        NaN    542550.0
#
#                                                      text category
# 812127  It does run, and gives very valid looking esti...  comment
# 812128  It seems to me that you are correct; the doubl...  comment
# 812129  It wouldn't be the first time a grader has mis...  comment
# 812130  The basic idea is to compare the clustering co...  comment
# 812131  As per your other question, your data does not...  comment

# %%
def process_text(text):
    # lower text
    text = text.lower()
    # tokenize_text
    text = [word for word in word_tokenize(text)]
    # join all
    text = " ".join(text)
    return(text)

# %%
# Adds a new column 'Cleaned_text'
df['Processed_text'] = df['text'].apply(lambda x: process_text(x))

# %%
df.iloc[0:1000,:]
# Out:
#      post_id  parent_id  comment_id  \
# 0          1        NaN         NaN
# 1          2        NaN         NaN
# 2          3        NaN         NaN
# 3          4        NaN         NaN
# 4          6        NaN         NaN
# ..       ...        ...         ...
# 995     6182        NaN         NaN
# 996     6189        NaN         NaN
# 997     6206        NaN         NaN
# 998     6208        NaN         NaN
# 999     6219        NaN         NaN
#
#                                                   text category  \
# 0                        Eliciting priors from experts    title
# 1                                   What is normality?    title
# 2    What are some valuable Statistical Analysis op...    title
# 3    Assessing the significance of differences in d...    title
# 4    The Two Cultures: statistics vs. machine learn...    title
# ..                                                 ...      ...
# 995  Predicting number of events with 99.9% probabi...    title
# 996  What is the interpretation of interquartile ra...    title
# 997  How to plot decision boundary in R for logisti...    title
# 998  Should I include an argument to request type-I...    title
# 999                           What does RMS stand for?    title
#
#                                         Processed_text
# 0                        eliciting priors from experts
# 1                                  what is normality ?
# 2    what are some valuable statistical analysis op...
# 3    assessing the significance of differences in d...
# 4    the two cultures : statistics vs. machine lear...
# ..                                                 ...
# 995  predicting number of events with 99.9 % probab...
# 996  what is the interpretation of interquartile ra...
# 997  how to plot decision boundary in r for logisti...
# 998  should i include an argument to request type-i...
# 999                          what does rms stand for ?
#
# [1000 rows x 6 columns]

# %%
df.iloc[ : 999,:].to_csv('stackexchange_812k_v1.csv', index=False) # Save first 1000 rows to csv
